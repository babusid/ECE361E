# %%
# importing the required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('log.csv',index_col=False)
tseries = df['time'].to_numpy()
core4util = df['usage_c4'].to_numpy()
print(df.head())
# Out:
#            time      W  usage_c0  usage_c1  usage_c2  usage_c3  usage_c4  \
# 0  1.676057e+09  0.000     0.333      0.50       0.0     0.000       1.0
# 1  1.676057e+09  0.000     0.200      0.10       0.3     0.059       1.0
# 2  1.676057e+09  0.000     0.000      0.00       0.0     0.048       1.0
# 3  1.676057e+09  5.603     0.050      0.00       0.0     0.048       1.0
# 4  1.676057e+09  5.603     0.105      0.19       0.1     0.053       1.0
#
#    usage_c5  usage_c6  usage_c7  temp4  temp5  temp6  temp7
# 0      0.50     0.600     0.333   51.0   47.0   44.0   39.0
# 1      0.10     0.263     0.211   53.0   43.0   43.0   38.0
# 2      0.00     0.050     0.050   53.0   42.0   42.0   38.0
# 3      0.05     0.000     0.053   53.0   41.0   42.0   38.0
# 4      0.30     0.350     0.211   52.0   46.0   46.0   39.0

# %%
plt.figure()
plt.plot(tseries,core4util)
plt.show()
